# %% [markdown]
# ¡Hola, Carmen!
#
# Mi nombre es Tonatiuh Cruz. Me complace revisar tu proyecto hoy.
#
# Al identificar cualquier error inicialmente, simplemente los destacaré. Te animo a localizar y abordar los problemas de forma independiente como parte de tu preparación para un rol como data-analyst. En un entorno profesional, tu líder de equipo seguiría un enfoque similar. Si encuentras la tarea desafiante, proporcionaré una pista más específica en la próxima iteración.
#
# Encontrarás mis comentarios a continuación - **por favor no los muevas, modifiques o elimines**.
#
# Puedes encontrar mis comentarios en cajas verdes, amarillas o rojas como esta:
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Éxito. Todo está hecho correctamente.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Observaciones. Algunas recomendaciones.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Necesita corrección. El bloque requiere algunas correcciones. El trabajo no puede ser aceptado con comentarios en rojo.
# </div>
#
# Puedes responderme utilizando esto:
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante.</b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Resumen de la revisión 1</b> <a class="tocSkip"></a>
#
# Hola, Carmen! Has hecho un excelente trabajo al realizar el proyecto, cargaste correctamente la información y la limpieza de esta información.
#
# Sigue con el excelente trabajo!
# </div>

# %% [markdown]
# # ¡Llena ese carrito!

# %% [markdown]
# # Introducción
#
# Instacart es una plataforma de entregas de comestibles donde la clientela puede registrar un pedido y hacer que se lo entreguen, similar a Uber Eats y Door Dash.
# El conjunto de datos que te hemos proporcionado tiene modificaciones del original. Redujimos el tamaño del conjunto para que tus cálculos se hicieran más rápido e introdujimos valores ausentes y duplicados. Tuvimos cuidado de conservar las distribuciones de los datos originales cuando hicimos los cambios.
#
# Debes completar tres pasos. Para cada uno de ellos, escribe una breve introducción que refleje con claridad cómo pretendes resolver cada paso, y escribe párrafos explicatorios que justifiquen tus decisiones al tiempo que avanzas en tu solución.  También escribe una conclusión que resuma tus hallazgos y elecciones.

# %% [markdown]
# ## Diccionario de datos
#
# Hay cinco tablas en el conjunto de datos, y tendrás que usarlas todas para hacer el preprocesamiento de datos y el análisis exploratorio de datos. A continuación se muestra un diccionario de datos que enumera las columnas de cada tabla y describe los datos que contienen.
#
# - `instacart_orders.csv`: cada fila corresponde a un pedido en la aplicación Instacart.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'user_id'`: número de ID que identifica de manera única la cuenta de cada cliente.
#     - `'order_number'`: el número de veces que este cliente ha hecho un pedido.
#     - `'order_dow'`: día de la semana en que se hizo el pedido (0 si es domingo).
#     - `'order_hour_of_day'`: hora del día en que se hizo el pedido.
#     - `'days_since_prior_order'`: número de días transcurridos desde que este cliente hizo su pedido anterior.
# - `products.csv`: cada fila corresponde a un producto único que pueden comprar los clientes.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'product_name'`: nombre del producto.
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
# - `order_products.csv`: cada fila corresponde a un artículo pedido en un pedido.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'add_to_cart_order'`: el orden secuencial en el que se añadió cada artículo en el carrito.
#     - `'reordered'`: 0 si el cliente nunca ha pedido este producto antes, 1 si lo ha pedido.
# - `aisles.csv`
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'aisle'`: nombre del pasillo.
# - `departments.csv`
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
#     - `'department'`: nombre del departamento.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# ¡Hola! Excelente trabajo desarrollando la introducción y el diccionario de datos. Esto es crucial para cualquier proyecto, ya que establece una guía clara sobre los pasos a seguir. Tener estos elementos bien definidos desde el principio nos permite trabajar de manera más organizada y eficiente. En un futuro lo podrías complementar con una tabla de contenido.
# </div>

# %% [markdown]
# # Paso 1. Descripción de los datos
#
# Lee los archivos de datos (`/datasets/instacart_orders.csv`, `/datasets/products.csv`, `/datasets/aisles.csv`, `/datasets/departments.csv` y `/datasets/order_products.csv`) con `pd.read_csv()` usando los parámetros adecuados para leer los datos correctamente. Verifica la información para cada DataFrame creado.

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan de solución para el Paso 1. Descripción de los datos.

# %%
# importar librerías
import pandas as pd
import matplotlib.pyplot as plt

# %%
# leer conjuntos de datos en los DataFrames
df_instacart=pd.read_csv("/datasets/instacart_orders.csv", sep=";")

df_products=pd.read_csv("/datasets/products.csv", sep=";")

df_order_products=pd.read_csv("/datasets/order_products.csv", sep=";")

df_aisles=pd.read_csv("/datasets/aisles.csv", sep=";")

df_departments=pd.read_csv("/datasets/departments.csv", sep=";")

# %%
# mostrar información del DataFrame
df_instacart.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB

# %%
# mostrar información del DataFrame
df_products.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
# mostrar información del DataFrame
df_order_products.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           4545007 non-null  int64
#  1   product_id         4545007 non-null  int64
#  2   add_to_cart_order  4544171 non-null  float64
#  3   reordered          4545007 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB

# %%
# mostrar información del DataFrame
df_aisles.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %%
# mostrar información del DataFrame
df_departments.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy buen trabajo con la carga de la información

# %% [markdown]
# ## Conclusiones
#
# Descripción de los datos.
#
# El archivo instacart_orders.csv presenta datos ausentes en la columna "days_since_prior_order".
# El archivo products.csv presenta datos ausentes en la columna "product_name".
# El archivo order_products.csv presenta datos ausentes en la columna "add_to_cart_order".

# %% [markdown]
# # Paso 2. Preprocesamiento de los datos
#
# Preprocesa los datos de la siguiente manera:
#
# - Verifica y corrige los tipos de datos (por ejemplo, asegúrate de que las columnas de ID sean números enteros).
# - Identifica y completa los valores ausentes.
# - Identifica y elimina los valores duplicados.
#
# Asegúrate de explicar qué tipos de valores ausentes y duplicados encontraste, cómo los completaste o eliminaste y por qué usaste esos métodos. ¿Por qué crees que estos valores ausentes y duplicados pueden haber estado presentes en el conjunto de datos?

# %% [markdown]
# ## Plan de solución
#
# Preprocesamiento de los datos.
#
# Se hará un exploracion de los datos a todos los 5 DataFrames con info() y head(), paso siguiente analizaremos los datos ausentes con isna().sum(), y los datos duplicados con duplicated().

# %% [markdown]
# ## Encuentra y elimina los valores duplicados (y describe cómo tomaste tus decisiones).

# %% [markdown]
# ### `orders` data frame

# %%
# Revisa si hay pedidos duplicados
print(df_instacart.duplicated().sum())
#VER LOS 15 DUPLICADOS del DataFrame
df_instacart[df_instacart.duplicated()]
# Out:
# 15
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 145574    794638    50898            24          3                  2
# 223105   2160484   107525            16          3                  2
# 230807   1918001   188546            14          3                  2
# 266232   1782114   106752             1          3                  2
# 273805   1112182   202304            84          3                  2
# 284038   2845099    31189            11          3                  2
# 311713   1021560    53767             3          3                  2
# 321100    408114    68324             4          3                  2
# 323900   1919531   191501            32          3                  2
# 345917   2232988    82565             1          3                  2
# 371905    391768    57671            19          3                  2
# 394347    467134    63189            21          3                  2
# ...

# %% [markdown]
# ¿Tienes líneas duplicadas? Si sí, ¿qué tienen en común?
#
# Sí hay líneas duplicadas y tienen en común el día y la hora

# %%
# Basándote en tus hallazgos,
# Verifica todos los pedidos que se hicieron el miércoles a las 2:00 a.m.
filter_day= df_instacart["order_dow"]==3
filter_hour= df_instacart["order_hour_of_day"]==2
df_instacart[(filter_day)&(filter_hour)]
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 4838     2766110   162084            41          3                  2
# 5156     2190225   138285            18          3                  2
# 15506     553049    58599            13          3                  2
# 18420     382357   120200            19          3                  2
# 24691     690242    77357             2          3                  2
# ...          ...      ...           ...        ...                ...
# 457013   3384021    14881             6          3                  2
# 458816    910166   164782            18          3                  2
# 459635   1680532   106435             6          3                  2
# 468324    222962    54979            59          3                  2
# 477526   2592344    46860            38          3                  2
#
#         days_since_prior_order
# 4838                      16.0
# 5156                      11.0
# ...

# %% [markdown]
# ¿Qué sugiere este resultado?
#
# Posiblemente un error

# %%
# Elimina los pedidos duplicados
df_instacart.drop_duplicates(inplace=True)

# %%
# Vuelve a verificar si hay filas duplicadas
df_instacart.duplicated().sum()
# Out:
# 0

# %%
# Vuelve a verificar únicamente si hay IDs duplicados de pedidos
df_instacart["order_id"].duplicated().sum()
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos
#
# Se hizo un analisis para encontrar posibles duplicados. Se encontraron 15 duplicados y estos se encontraron en las columnas "order_dow" y "order_hour_of_day" solamente porque coincidian con pedidos hechos el miercoles a las 2 de la mañana. Se hizo un filtrado para ver todos los pedidos hechos ese día y a esa hora. Se tuvieron 121 filas, si todos los pedidos hechos ese día y a esa hora estuvieran duplicados tendrian que tener multiplos de 15, por lo tanto fue un error y se proceden a eliminarlos. Para hacer una verificación se analizaron si la columna "order_id" que es el id único para cada orden tenia duplicados y mostro 0.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Gran trabajo con el análisis de duplicados

# %% [markdown]
# ### `products` data frame

# %%
# Verifica si hay filas totalmente duplicadas
df_products.duplicated().sum()
# Out:
# 0

# %%
# Revisa únicamente si hay ID de departamentos duplicados
df_products["department_id"].duplicated().sum()
# Out:
# 49673

# %%
# Revisa únicamente si hay nombres duplicados de productos (convierte los nombres a letras mayúsculas para compararlos mejor)
print(df_products["product_name"].duplicated().sum())
df_products["product_name"]=df_products["product_name"].str.upper()
# Out:
# 1257

# %%
# Revisa si hay nombres duplicados de productos no faltantes
#df_products["product_name"].duplicated().sum()
#Corregido
df_products[(~df_products['product_name'].isna()) & df_products['product_name'].duplicated()]
# Out:
#        product_id                                     product_name  aisle_id  \
# 2058         2059                                  BIOTIN 1000 MCG        47
# 5455         5456                 GREEN TEA WITH GINSENG AND HONEY        96
# 5558         5559                           CREAM OF MUSHROOM SOUP        69
# 7558         7559                        CINNAMON ROLLS WITH ICING       105
# 9037         9038                           AMERICAN CHEESE SLICES        21
# ...           ...                                              ...       ...
# 49689       49690                    HIGH PERFORMANCE ENERGY DRINK        64
# 49690       49691                    ORIGINAL PANCAKE & WAFFLE MIX       130
# 49691       49692  ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR       130
# 49692       49693                           SPRING WATER BODY WASH       127
# 49693       49694                          BURRITO- STEAK & CHEESE        38
#
#        department_id
# 2058              11
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
#  Solamente la verificación de duplicados te recomiendo hacerla sobre la varialble de nombre del producto. Para esto te puedes guiar del siguiente ejemplo:
#
#     products[(~products['product_name'].isna()) & products['product_name'].duplicated()]
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Gran trabajo con el ajuste!

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# Aparentemente no los hay

# %% [markdown]
# ### `departments` data frame

# %%
# Revisa si hay filas totalmente duplicadas
df_departments.duplicated().sum()
# Out:
# 0

# %%
# Revisa únicamente si hay IDs duplicadas de productos
df_departments["department_id"].duplicated().sum()
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# No se encontaron valores duplicados para este DataFrame. Contiene 21 filas con el nombre de departamento y el ID del departamento.

# %% [markdown]
# ### `aisles` data frame

# %%
# Revisa si hay filas totalmente duplicadas
df_aisles.duplicated().sum()
# Out:
# 0

# %%
# Revisa únicamente si hay IDs duplicadas de pasillos
df_aisles["aisle_id"].duplicated().sum()
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# No se encontraron valores duplicados para este DataFrame. Contiene 134 entradas con el nombre del pasillo y el ID del mismo.

# %% [markdown]
# ### `order_products` data frame

# %%
# Revisa si hay filas totalmente duplicadas
df_order_products.duplicated().sum()
# Out:
# 0

# %%
# Vuelve a verificar si hay cualquier otro duplicado engañoso
df_order_products.duplicated(subset=["order_id", "product_id"]).sum()
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# No se encontraron valores duplicados y para corroborar se analizaron los valores duplicados en las columnas que son especificas para el DataFrame que son las que contienen ID's.

# %% [markdown]
# ## Encuentra y elimina los valores ausentes
#
# Al trabajar con valores duplicados, pudimos observar que también nos falta investigar valores ausentes:
#
# * La columna `'product_name'` de la tabla products.
# * La columna `'days_since_prior_order'` de la tabla orders.
# * La columna `'add_to_cart_order'` de la tabla order_productos.

# %% [markdown]
# ### `products` data frame

# %%
# Encuentra los valores ausentes en la columna 'product_name'
df_products[df_products["product_name"].isna()]
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Posiblemente los valores faltantes esten relacionados al pasillo 100, departamento 21

# %%
#  ¿Todos los nombres de productos ausentes están relacionados con el pasillo con ID 100?
df_products[(df_products["aisle_id"]!=100)&(df_products["product_name"].isna())]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id]
# Index: []

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Todos los valores ausentes se encuentran en el pasillo ID 100 ya que arrojo un DataFrame vacío.

# %%
# ¿Todos los nombres de productos ausentes están relacionados con el departamento con ID 21?
df_products[(df_products["department_id"]!=21)&(df_products["product_name"].isna())]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id]
# Index: []

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Tambien todos los valores ausentes estan en el pasillo 21.

# %%
# Usa las tablas department y aisle para revisar los datos del pasillo con ID 100 y el departamento con ID 21.
df_products[(df_products["aisle_id"]==100)&(df_products["department_id"]==21)]
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.

# %%
# Completa los nombres de productos ausentes con 'Unknown'
df_products["product_name"].fillna("Unknow", inplace=True)

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy buen trabajo!! Desarrollaste de manera excelente el análisis de valores faltantes y los llenaste con "unknown".

# %% [markdown]
# ### `orders` data frame

# %%
# Encuentra los valores ausentes
df_instacart[df_instacart["days_since_prior_order"].isna()]
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 28        133707   182261             1          3                 10
# 96        787445    25685             1          6                 18
# 100       294410   111449             1          0                 19
# 103      2869915   123958             1          4                 16
# 104      2521921    42286             1          3                 18
# ...          ...      ...           ...        ...                ...
# 478895   2589657   205028             1          0                 16
# 478896   2222353   141211             1          2                 13
# 478922   2272807   204154             1          1                 15
# 478926   2499542    68810             1          4                 19
# 478945   1387033    22496             1          5                 14
#
#         days_since_prior_order
# 28                         NaN
# 96                         NaN
# ...

# %%
# ¿Hay algún valor ausente que no sea el primer pedido del cliente?
df_instacart[df_instacart["order_number"]==1]
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 28        133707   182261             1          3                 10
# 96        787445    25685             1          6                 18
# 100       294410   111449             1          0                 19
# 103      2869915   123958             1          4                 16
# 104      2521921    42286             1          3                 18
# ...          ...      ...           ...        ...                ...
# 478895   2589657   205028             1          0                 16
# 478896   2222353   141211             1          2                 13
# 478922   2272807   204154             1          1                 15
# 478926   2499542    68810             1          4                 19
# 478945   1387033    22496             1          5                 14
#
#         days_since_prior_order
# 28                         NaN
# 96                         NaN
# ...

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# Se analizaron los valores ausentes para la columna "days_since_prior_order" y arrojo 28817 filas pero tenian en la columna "order_number" que era la primer compra del cliente. A su vez se analizaron todas las filas con "order_number" de primera compra y arrojaron las mismas 28817 filas por lo que todos eso valores ausentes estan correctos.

# %% [markdown]
# ### `order_products` data frame

# %%
# Encuentra los valores ausentes
df_order_products[df_order_products["add_to_cart_order"].isna()]
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 737       2449164        5068                NaN          0
# 9926      1968313       43867                NaN          0
# 14394     2926893       11688                NaN          0
# 16418     1717990        4142                NaN          0
# 30114     1959075       42828                NaN          1
# ...           ...         ...                ...        ...
# 4505662   1800005        7411                NaN          0
# 4511400   1633337         260                NaN          0
# 4517562    404157        9517                NaN          0
# 4534112   1673227       17835                NaN          0
# 4535739   1832957       17949                NaN          1
#
# [836 rows x 4 columns]

# %%
# ¿Cuáles son los valores mínimos y máximos en esta columna?
print("El valor mínimo es:", df_order_products["add_to_cart_order"].min(), "y el valor máximo es:", df_order_products["add_to_cart_order"].max())
# Out:
# El valor mínimo es: 1.0 y el valor máximo es: 64.0

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Que el conteo en el que se agregan los articulos al carrito de compra solo llega hasta 64.

# %%
# Guarda todas las IDs de pedidos que tengan un valor ausente en 'add_to_cart_order'
order_id_nan=df_order_products[df_order_products["add_to_cart_order"].isna()]["order_id"].unique()
order_id_nan
# Out:
# array([2449164, 1968313, 2926893, 1717990, 1959075,  844733,   61355,
#         936852,  264710, 1564093,  129627,  293169, 2849370, 1386261,
#        3308010,  903110, 2136777, 3347453, 1888628,  165801, 2094761,
#        1038146, 2997021,  813364, 2256933,  171934, 2409109, 1730767,
#        1169835,  733526,  404157, 3125735,  747668, 1800005, 1961723,
#         871281,  388234, 1648217, 1477139,  102236, 1021563, 1832957,
#        2721963,  678116, 1220886, 1673227, 2999801, 1633337, 2470674,
#        2625444, 1677118, 2479011, 3383594, 1183255, 1713430, 2652650,
#        1598369, 1916118,  854647, 1302315,  888470,  180546, 2621907,
#        1308785, 2729254,    9310, 2170451, 2979697, 1625713, 1529171])

# %%
# ¿Todos los pedidos con valores ausentes tienen más de 64 productos?
# Agrupa todos los pedidos con datos ausentes por su ID de pedido.
order_products_nan=df_order_products[df_order_products["order_id"].isin(order_id_nan)]
nan_group=order_products_nan.groupby("order_id")["product_id"].count()
# Cuenta el número de 'product_id' en cada pedido y revisa el valor mínimo del conteo.
print(nan_group.min())
# Out:
# 65

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Una vez que se llegaba a 64 en el conteo, lo démas se rellenaba con NaN.

# %%
# Remplaza los valores ausentes en la columna 'add_to_cart? con 999 y convierte la columna al tipo entero.
df_order_products["add_to_cart_order"].fillna(999, inplace=True)
rename_nan_order_products=df_order_products[(df_order_products["add_to_cart_order"]==999)]
rename_nan_order_products#verificar que esten modificados los NaN
df_order_products["add_to_cart_order"].astype("int")
# Out:
# 0          17
# 1           1
# 2           1
# 3          35
# 4           5
#            ..
# 4545002    12
# 4545003     9
# 4545004     4
# 4545005     8
# 4545006     9
# Name: add_to_cart_order, Length: 4545007, dtype: int64

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Excelente trabajo con este ejercicio, completaste de manera perfecta los valores ausentes con 999.

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 2. Preprocesamiento de los datos
#
# Es importante que antes de proceder a hacer analisis con los datos, se explore que no haya datos duplicados para no sobreestimar resultados, que no tenga valores ausentes ó indagar a que se debe esos valores y que los datos que sean númericos y se destinen a anlizar, esten en tipo entero.

# %% [markdown]
# # Paso 3. Análisis de los datos
#
# Una vez los datos estén procesados y listos, haz el siguiente análisis:

# %% [markdown]
# # [A] Fácil (deben completarse todos para aprobar)
#
# 1. Verifica que los valores en las columnas `'order_hour_of_day'` y `'order_dow'` en la tabla orders sean razonables (es decir, `'order_hour_of_day'` oscile entre 0 y 23 y `'order_dow'` oscile entre 0 y 6).
# 2. Crea un gráfico que muestre el número de personas que hacen pedidos dependiendo de la hora del día.
# 3. Crea un gráfico que muestre qué día de la semana la gente hace sus compras.
# 4. Crea un gráfico que muestre el tiempo que la gente espera hasta hacer su siguiente pedido, y comenta sobre los valores mínimos y máximos.

# %% [markdown]
# ### [A1] Verifica que los valores sean sensibles

# %%
print(df_instacart["order_hour_of_day"].head(1))
print(df_instacart["order_hour_of_day"].min())
print(df_instacart["order_hour_of_day"].max())
# Out:
# 0    13
# Name: order_hour_of_day, dtype: int64
# 0
# 23

# %%
print(df_instacart["order_dow"].head(1))
print(df_instacart["order_dow"].min())
print(df_instacart["order_dow"].max())
# Out:
# 0    6
# Name: order_dow, dtype: int64
# 0
# 6

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Se analizó el tipo de dato y sus valores mínimos y máximos para revisar que tengan coherencia para la columna.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario Revisor</b> <a class="tocSkip"></a>
#
# Muy buena forma de revisar que los valores sean sensibles. Otra forma de hacerlo que puedes explorar más adeltante es el uso de la función  .value_counts().
# </div>

# %% [markdown]
# ### [A2] Para cada hora del día, ¿cuántas personas hacen órdenes?

# %%
orders_for_day=df_instacart.groupby("order_hour_of_day")["user_id"].count()
orders_for_day.plot(kind='bar')
plt.title('Número de ordenes por día')
plt.xlabel('Hora del día')
plt.ylabel('Número de ordenes')
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Se muestra el conteo de los pedidos que hay para cada hora. El mayor número de ordenes se muestran entre las 10-16 horas.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario Revisor</b> <a class="tocSkip"></a>
#
# Solamente recuerda completar esto con una gráfica

# %% [markdown]
# ### [A3] ¿Qué día de la semana compran víveres las personas?

# %%
buy_for_day=df_instacart.groupby("order_dow")["user_id"].count()
#buy_for_day.rename(index={"0":"Domingo", "1":"Lunes", "2":"Martes", "3":"Miercoles", "4":"Jueves", "5":"Viernes", "6":"Sábado"})
buy_for_day
buy_for_day.plot(kind="bar")
plt.title('Compras por día')
plt.xlabel('Día de la semana')
plt.ylabel('Número de compras')
plt.xticks([0,1,2,3,4,5,6],['Dom','Lun','Mar','Mie','Jue','Vie','Sáb'])
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# El domingo y el lunes son los días que mas compras se reportan

# %% [markdown]
# ### [A4] ¿Cuánto tiempo esperan las personas hasta hacer otro pedido? Comenta sobre los valores mínimos y máximos.

# %%
print("Tiempo de espera mínimo:",df_instacart["order_hour_of_day"].min(),"días")
print("Tiempo de espera máximo:",df_instacart["order_hour_of_day"].max(),"días")
# Out:
# Tiempo de espera mínimo: 0 días
# Tiempo de espera máximo: 23 días

# %% [markdown]
# Escribe aquí tus conclusiones:
# Las personas tardan en hacer un nuevo pedido hasta 23 días.

# %% [markdown]
# # [B] Intermedio (deben completarse todos para aprobar)
#
# 1. ¿Existe alguna diferencia entre las distribuciones `'order_hour_of_day'` de los miércoles y los sábados? Traza gráficos de barra de `'order_hour_of_day'` para ambos días en la misma figura y describe las diferencias que observes.
# 2. Grafica la distribución para el número de órdenes que hacen los clientes (es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).
# 3. ¿Cuáles son los 20 principales productos que se piden con más frecuencia (muestra su identificación y nombre)?

# %% [markdown]
# ### [B1] Diferencia entre miércoles y sábados para  `'order_hour_of_day'`. Traza gráficos de barra para los dos días y describe las diferencias que veas.

# %%
orders_wednesday=df_instacart[df_instacart["order_dow"]==3]#filtrado para miercoles
orders_wednesday
orders_wednesday=orders_wednesday["order_hour_of_day"].value_counts().sort_index()#agrupacion del filtrado con la hora
orders_wednesday
# Out:
# 0      373
# 1      215
# 2      106
# 3      101
# 4      108
# 5      170
# 6      643
# 7     1732
# 8     3125
# 9     4490
# 10    5026
# 11    5004
# 12    4688
# 13    4674
# 14    4774
# 15    5163
# 16    4976
# 17    4175
# 18    3463
# 19    2652
# 20    1917
# 21    1450
# 22    1154
# 23     718
# Name: order_hour_of_day, dtype: int64

# %%
orders_saturday=df_instacart[df_instacart["order_dow"]==6]#filtrado para sabado
orders_saturday
orders_saturday=orders_saturday["order_hour_of_day"].value_counts().sort_index()#agrupacion del filtrado con la hora
orders_saturday
# Out:
# 0      464
# 1      254
# 2      177
# 3      125
# 4      118
# 5      161
# 6      451
# 7     1619
# 8     3246
# 9     4311
# 10    4919
# 11    5116
# 12    5132
# 13    5323
# 14    5375
# 15    5188
# 16    5029
# 17    4295
# 18    3338
# 19    2610
# 20    1847
# 21    1473
# 22    1185
# 23     893
# Name: order_hour_of_day, dtype: int64

# %%
days_agrup=pd.concat([orders_wednesday, orders_saturday],axis=1)# juntamos los dos Series filtrados por columnas
days_agrup
days_agrup.columns=["wednesday","saturday"]# renombramos columnas
days_agrup
# Out:
#     wednesday  saturday
# 0         373       464
# 1         215       254
# 2         106       177
# 3         101       125
# 4         108       118
# 5         170       161
# 6         643       451
# 7        1732      1619
# 8        3125      3246
# 9        4490      4311
# 10       5026      4919
# 11       5004      5116
# 12       4688      5132
# 13       4674      5323
# 14       4774      5375
# 15       5163      5188
# 16       4976      5029
# 17       4175      4295
# 18       3463      3338
# 19       2652      2610
# 20       1917      1847
# 21       1450      1473
# 22       1154      1185
# 23        718       893

# %%
days_agrup.plot(kind="bar")
plt.title('Wednesday Vs Saturday')
plt.xlabel('Hour of day')
plt.ylabel('Orders number')
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Se compararon las compras hechas a lo largo del día entre el día miercoles y el día sabado, se podría suponer que el sábado aumenta el nivel de compras al medio día.

# %% [markdown]
# ### [B2] ¿Cuál es la distribución para el número de pedidos por cliente?

# %%
ord_for_client=df_instacart.groupby("user_id")["order_id"].count()

# %%
ord_for_client.plot(kind='hist',bins=25)
plt.title('Distribución total de ordenes')
plt.xlabel('Número de ordenes')
plt.ylabel('Número de clientes')
plt.xticks(range(0,15,3))
plt.yticks(range(0,90000,15000))
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
# Los usuarios tienden a realizar 1 orden por usuario.

# %% [markdown]
# ### [B3] ¿Cuáles son los 20 productos más populares (muestra su ID y nombre)?

# %%
merge_orders=df_order_products.merge(df_products)
merge_orders_fil=merge_orders[merge_orders["reordered"]==1]

# %%
top_20_products=merge_orders_fil.value_counts(ascending=False)
top_20_products.head(20)
# Out:
# order_id  product_id  add_to_cart_order  reordered  product_name                                 aisle_id  department_id
# 4         10054       5.0                1          KELLOGG'S NUTRI-GRAIN APPLE CINNAMON CEREAL  48        14               1
# 2278697   24852       2.0                1          BANANA                                       24        4                1
# 2278692   47766       4.0                1          ORGANIC AVOCADO                              24        4                1
# 2278693   4799        11.0               1          SHREDDED PARMESAN                            21        16               1
#           5194        10.0               1          ORGANIC BUNNY FRUIT SNACKS BERRY PATCH       50        19               1
#           8859        1.0                1          NATURAL SPRING WATER                         115       7                1
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy buen desarrollo de la sección. Desarrollaste de buena manera todos los análisis y lo complementaste con dos gráfica.
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones

# %% [markdown]
# # [C] Difícil (deben completarse todos para aprobar)
#
# 1. ¿Cuántos artículos suelen comprar las personas en un pedido? ¿Cómo es la distribución?
# 2. ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?
# 3. Para cada producto, ¿cuál es la tasa de repetición del pedido (número de repeticiones de pedido/total de pedidos?
# 4. Para cada cliente, ¿qué proporción de los productos que pidió ya los había pedido? Calcula la tasa de repetición de pedido para cada usuario en lugar de para cada producto.
# 5. ¿Cuáles son los 20 principales artículos que la gente pone primero en sus carritos (muestra las IDs de los productos, sus nombres, y el número de veces en que fueron el primer artículo en añadirse al carrito)?

# %% [markdown]
# ### [C1] ¿Cuántos artículos compran normalmente las personas en un pedido? ¿Cómo es la distribución?

# %%
mean_orders=df_order_products.groupby("order_id")["product_id"].count().sort_values()

# %%
mean_orders.plot(kind='hist',bins=25)
plt.title('Products/user')
plt.xlabel('Products')
plt.ylabel('Number/orders')
plt.xticks(range(0,75,5))
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Los usuarios compran entre 1 y 5 articulos por orden.

# %% [markdown]
# ### [C2] ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?

# %%
#Se unieron 2 DF con informacion de utilidad, los productos y las ordenes de los productos
top_products=pd.merge(df_products,df_order_products)

# %%
# Se agrupan columnas del nombre del producto con la de re-ordenamientos
group_top_products=top_products.groupby("product_name")["reordered"].count().sort_values(ascending=False)
group_top_products.head(20)
# Out:
# product_name
# BANANA                      66050
# BAG OF ORGANIC BANANAS      53297
# ORGANIC STRAWBERRIES        37039
# ORGANIC BABY SPINACH        33971
# ORGANIC HASS AVOCADO        29773
# ORGANIC AVOCADO             24689
# LARGE LEMON                 21495
# STRAWBERRIES                20018
# LIMES                       19690
# ORGANIC WHOLE MILK          19600
# ORGANIC RASPBERRIES         19197
# ORGANIC YELLOW ONION        15898
# ORGANIC GARLIC              15292
# ORGANIC ZUCCHINI            14584
# ORGANIC BLUEBERRIES         13879
# CUCUMBER KIRBY              13675
# ORGANIC FUJI APPLE          12544
# ORGANIC LEMON               12232
# APPLE HONEYCRISP ORGANIC    11993
# ORGANIC GRAPE TOMATOES      11781
# Name: reordered, dtype: int64

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Los 20 productos que tienen mayor cantidad de re-ordenamientos son frutas y verduras.

# %% [markdown]
# ### [C3] Para cada producto, ¿cuál es la proporción de las veces que se pide y que se vuelve a pedir?

# %%
#reorders=pd.merge(df_instacart_orders, df_order_products)
#df_order_products.groupby("product_id")["reordered"].sum()

# %%
product_reordered = df_order_products.groupby("product_id").agg(
    n_reordered = ('reordered', 'sum'),
    n_total = ('reordered', 'count'),
)

product_reordered['proporción'] = product_reordered['n_reordered']/product_reordered['n_total']
product_reordered
# Out:
#             n_reordered  n_total  proporción
# product_id
# 1                   158      280    0.564286
# 2                     0       11    0.000000
# 3                    31       42    0.738095
# 4                    25       49    0.510204
# 7                     1        2    0.500000
# ...                 ...      ...         ...
# 49690                 4        5    0.800000
# 49691                31       72    0.430556
# 49692                 5       12    0.416667
# 49693                11       25    0.440000
# 49694                 3        9    0.333333
#
# [45573 rows x 3 columns]

# %% [markdown]
# Escribe aquí tus conclusiones

# %% [markdown]
# ### [C4] Para cada cliente, ¿qué proporción de sus productos ya los había pedido?

# %%
#Se unen dos DataFrame
user_reordered=df_instacart.merge(df_order_products)
user_reordered
#Se agrupan las columnas de interes y se agregan metodos matemáticos
user_reordered.groupby('order_number').agg(
    num_reordered = ('reordered', 'sum'),
    num_total = ('reordered', 'count'),
    proporcion = ('reordered', 'mean')
)
# Out:
#               num_reordered  num_total  proporcion
# order_number
# 1                         0     291928    0.000000
# 2                     77711     284160    0.273476
# 3                    110221     284875    0.386910
# 4                    115633     253116    0.456838
# 5                    116909     231626    0.504732
# ...                     ...        ...         ...
# 95                     1678       1972    0.850913
# 96                     1579       1866    0.846195
# 97                     1750       2007    0.871948
# 98                     1487       1728    0.860532
# 99                     1465       1738    0.842923
#
# [99 rows x 3 columns]

# %% [markdown]
# Escribe aquí tus conclusiones
# Se obtuvo la proporcion para cada cliente, de los productos que ya habia pedido anteriormente.

# %% [markdown]
# ### [C5] ¿Cuáles son los 20 principales artículos que las personas ponen primero en sus carritos?

# %%
# Uni 2 DataFrame con informacion necesaria
add_products = df_products.merge(df_order_products)
add_products
#Filtrado de los productos que primero se ponen en el carrito
add_products = add_products[add_products['add_to_cart_order'] == 1]
#Ordenan los productos más ordenados de mayor a menor para obtener el top 20
top_20=add_products.groupby("product_name")["add_to_cart_order"].value_counts().sort_values(ascending=False)
top_20.head(20)
# Out:
# product_name                 add_to_cart_order
# BANANA                       1.0                  15562
# BAG OF ORGANIC BANANAS       1.0                  11026
# ORGANIC WHOLE MILK           1.0                   4363
# ORGANIC STRAWBERRIES         1.0                   3946
# ORGANIC HASS AVOCADO         1.0                   3390
# ORGANIC BABY SPINACH         1.0                   3336
# ORGANIC AVOCADO              1.0                   3044
# SPRING WATER                 1.0                   2336
# STRAWBERRIES                 1.0                   2308
# ORGANIC RASPBERRIES          1.0                   2024
# SPARKLING WATER GRAPEFRUIT   1.0                   1914
# ORGANIC HALF & HALF          1.0                   1797
# LARGE LEMON                  1.0                   1737
# SODA                         1.0                   1733
# ORGANIC REDUCED FAT MILK     1.0                   1397
# LIMES                        1.0                   1370
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Solamente para este caso recuerda filtrar primero por los artículos que ponen primero en sus carritos y posterior hacemos el conteo y filtramos los primeros 20

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Gran trabajo con el ajuste!

# %% [markdown]
# Escribe aquí tus conclusiones
# Los productos que primero se agregan al carrito son productos de alimentos.

# %% [markdown]
# ### Conclusion general del proyecto:

# %% [markdown]
# Se analizo como es la naturaleza de compra de los clientes para una aplicación de compras. Mejores dias de venta y las horas de mayor trafico en pedidios, los productos más vendidos y los que se re-compran más veces.
